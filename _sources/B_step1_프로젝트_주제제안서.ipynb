# %% [markdown]
# # 프로젝트 주제 제안서 제출 안내
#
# 주제를 선정한 후 문제를 정의하고, 데이터를 수집, 정제, 분석 및 시각화하여 의미 있는 결과를 도출할 수 있는 주제 제안서를 작성해 제출하세요.
#
#
# - 주제: 자유롭게 결정
#
# - 아래 형식에 맞게 프로젝트 주제 제안서를 작성해 주세요.
# - 제출 자료: 지금 작성하고 있는 .ipynb파일
# - 파일 다운로드 방법 및 제출 장소 :
#   - 파일 >> 다운로드 >> .ipynb >> 여러분의 컴퓨터에 파일 다운로드 됨
#     - 다운로드한 파일은 윈도우에서 정상적으로 열리지 않을 수 있으나, 파일에는 이상이 없으므로 안심하셔도 됩니다.
#   - 제출장소: <font color="green"><strong>etl 우리 강좌의 게시판 >> 프로젝트 주제 제안서 제출 게시판에 업로드</strong></font>
# - 제출 기한: <font color="red">1월 14일까지</font>

# %% [markdown]
# ## 1.주제 선정 및 문제 정의
# - 선택한 주제와 이를 통해 해결하고자 하는 문제를 간략히 설명하세요.

# %% [markdown]
# ## 2.목표

# %% [markdown]
# - 해결하고자 하는 문제의 목표를 간략히 적어주세요.

# %% [markdown]
# ## 3.데이터 수집 방법
#
# - 사용하려는 데이터의 출처와 유형을 명시하고, 데이터를 어떻게 수집할지 적어주세요.

# %% [markdown]
# ## 4.데이터 정제 및 분석 방법
# - 수집한 데이터를 어떻게 정리하고 분석할지 계획을 구체적으로 작성하세요.

# %% [markdown]
# ## 5.시각화 및 스토리텔링 방향
#
# - 분석 결과를 어떤 방식으로 시각화하여 표현할 것인지와, 이를 통해 기대되는 활용 방안을 기술하세요.

# %% [markdown]
# ---
