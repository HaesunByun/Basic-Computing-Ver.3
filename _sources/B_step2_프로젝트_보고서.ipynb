# %% [markdown]
# # 기말 프로젝트 일정 및 제출 방법
# 주제를 정하여 문제 정의를 하고, 데이터를 수집, 정제, 분석, 시각화하여 제출하세요.
#
# - 주제 : 자유롭게 결정
#
# - 주제 제안서 제출 기한: <font color='red'>1월 14일(수)</font>, <font color='blue'> eTL 기말 프로젝트 주제 제안서 제출 게시판</font>에 게시
#   - 제출 이후 수정 가능
#
# - 발표 동영상과 PDF 자료 제출 기한: <font color='red'>1월 22일(목) 오전 9시</font>, <font color='blue'>eTL 기말 프로젝트 동영상/PDF 제출 게시판</font>에 게시
#   - 발표 동영상 파일
#   - PDF 파일
#
# - 발표회 일시:
#     - <font color="red">1월 22일, 수업시간</font>
#     - 이름순 발표
#
# - 보고서, 발표포스터 최종 제출: <font color='red'>1월 22일(목) 23시 59분</font>, <font color='blue'>eTL 과제>기말>[기말평가] 프로젝트</font>에 제출
#   - 보고서 파일(.ipynb 파일)
#   - .py 파일(있을 시)
#   - 발표포스터(.pptx 파일)
#   - 데이터파일(있을 시), 여러개일 경우 압축파일
#
# - 학생 투표 평가 기한: <font color='red'>1월 22일(목)</font>
#
# - 피드백 평가 기한: <font color='red'>1월 22일(목)</font>

# %% [markdown]
# # 프로젝프 평가 기준 및 수행 계획

# %% [markdown]
# ### 1.프로젝트 주제 제안서(3점)
#   - 제출 기한: <font color='red'>1월 14일(수)</font>
#   - 제출 장소: <font color='blue'> eTL 기말 프로젝트 주제 제안서 제출 게시판</font>에 게시
#     - **게시글 제목 : [주제제안서]작성자명(학번끝3자리): 프로젝트 주제명**
#     - 예
#       - [주제제안서]김철수(567): 인구수와 CCTV수 관계 분석
#       - (팀의 경우) [주제제안서](팀)강감찬(학번3자리), 신사임당(학번3자리), 이순신(학번3자리): 인구수와 CCTV수 관계 분석
#       - 반드시 제목 형식을 지켜주세요.
#   - 내용:
#     - 자유 주제를 선정한 후 문제를 정의하고, 데이터를 수집, 정제, 분석 및 시각화하여 의미 있는 결과를 도출할 수 있는 주제 제안서를 작성
#     - 출처가 있는 경우, 원본 링크와 함께 출처, 원작자를 명확히 표기
#
#   - 안내:
#     - 주제제안서는 조교&튜터의 피드백이 있습니다. 피드백을 받은 후, 수정이나 변경 가능합니다.
#     - 제출기한을 넘기면 1일당 1점, 최대 6점까지 감점합니다.

# %% [markdown]
# ---

# %% [markdown]
# ## 2.발표 동영상과 PDF 파일 자료 제출(2점)

# %% [markdown]
# - 제출장소: <font color="green"><strong>게시판 > 기말 프로젝트 동영상 발표/PDF 제출 게시판</strong></font>
# - 제출 기한 : <font color="red">1월 22일(목) 오전 9시 00분</font>
# - 내용:
#   - [발표 포스터 PPT 양식을 다운로드](https://github.com/HaesunByun/Basic-Computing/blob/gh-pages/_sources/%EB%B0%9C%ED%91%9C%ED%8F%AC%EC%8A%A4%ED%84%B0%EC%96%91%EC%8B%9D.pptx?raw=True)받아 발표자료를 만들고 5분 이내의 발표 동영상을 촬영한 후, 발표 포스터 파일을 PDF로 만들어 함께 업로드 제출합니다.
#   - 연구배경 및 필요성 등의 소제목을 바꿔도 되고, 영역을 키우거나 줄이는 등의 변경 가능합니다.
#   - 동영상 발표는 이름순으로 재생합니다.
#
# - 안내:
#   - 포스터 내용에 데이터의 출처를 반드시 넣습니다.
#   - 포스터 내용에 기본적인 설치 & 설정 내용은 넣지 않습니다.(예: 한글 폰트 설정, 크롬 옵션 설정 등)
#   - 발표 포스터 파일 제출시 PDF로 변환하여 제출합니다.(**PPT아니고 PDF 제출!**)
#   - 발표 포스터는 반드시 한장으로 작성합니다.
#   - 발표 포스터를 확대하면서 발표해도 되고, 혹은 별도로 발표 ppt를 여러장 만들어서 발표해도 됩니다. 단, 별도 발표 ppt를 만들더라도 반드시 발표 포스터는 주어진 양식에 따라 한장으로 제출해야 합니다.
#   - 미제출시 구제기회 없습니다.
#   - 지연 제출 시 1일당 1점, 최대 6점까지 감점합니다.
#   - 파일명 형식이 지켜지지 않거나 필요한 파일 업로드를 지키지 않았을 때 감점 1점
# - 파일명
#   - 이름_학번_프로젝트명.mp4(예, 홍길동_2024-15184_인구수와 CCTV수 관계분석.mp4)
#     - mp4, mov 가능합니다.
#   - 이름_학번_프로젝트명.pdf(예, 홍길동_2024-15184_인구수와 CCTV수 관계분석.pdf)
#   - (팀의 경우)강감찬,신사임당,이순신_인구수와 CCTV수 관계 분석.mp4
#   - (팀의 경우)강감찬,신사임당,이순신_인구수와 CCTV수 관계 분석.pdf

# %% [markdown]
# ## 3.발표평가(12점)
#
#
# - 주제선정
#   - 관심도 높은, 흥미로운, 의미가 있는 주제를 선정했는지 판단
# - 발표내용 및 구성
#   - 발표 구성이 적절한지 판단
#   - 발표 내용이 충실한지 판단
#   - 그래프 결과와 결론을 잘 도출 했는지 판단
#   - 발표 능력과 태도 판단
#   - 동영상 발표의 품질
# - 교수자+조교+튜터가  평가한  점수의  평균점수로 부여

# %% [markdown]
# ##4.최종 자료 제출 및 보고서 평가(5점)

# %% [markdown]
# - 제출자료
#
#   - 코드 + 보고서 : 지금 작성하고 있는 .ipynb파일
#
#   - 2번에서 작성한 발표 포스터 PPT 파일(**PDF아니고 pptx)!!!!**)
#
#   - 프로젝트에서 사용한 데이터 파일(있을 시)
#   - 파일들을 압축하지 말것(단, 데이터파일이 여러개 일 경우 데이터파일만 하나의 파일로 압축)
#
# - 제출 기한 :
#   - <font color="red">1월 22일 23시 59분 59초(시간 엄수!!)</font>
#
# - 제출 장소: <font color="green"><strong> etl 우리 강좌 > 과제 > [기말평가]프로젝트</strong></font>에 제출
#
# - 파일명
#   - 이름_학번_프로젝트명.ipynb(예, 홍길동_2024-15184_인구수와 CCTV수 관계분석.ipynb)
#   - 이름_학번_프로젝트명.pptx(예, 홍길동_2024-15184_인구수와 CCTV수 관계분석.pptx)
#   - (팀의 경우)강감찬,신사임당,이순신_인구수와 CCTV수 관계 분석.ipynb
#   - (팀의 경우)강감찬,신사임당,이순신_인구수와 CCTV수 관계 분석.pptx
#
# - 안내
#   - 지연 제출 시 1일당 1점, 최대 6점까지 감점합니다.
#   - 파일명 형식이 지켜지지 않거나 필요한 파일 업로드가 지켜지지 않았을 때 감점 1점
#   - 팀의 경우라도 모든 팀원이 개별로 업로드해주세요.
#   - ETL에 업로드할 때 파일명이 동일한 경우 파일명 뒤에 (숫자)가 자동으로 붙을 수 있으나, 정상적인 동작이며 이에 따른 감점은 없습니다.

# %% [markdown]
# ##5.학생투표평가(최대 3점)
#
# - 모든 학생들은 다른 학생들의 발표를 듣고, 본인을 제외한 다른 학생의 프로젝트 5개를 골라 구글 설문으로 투표를 진행
#   - 가장 인상적인 기여를 했거나 문제에 대한 구현이 훌륭한 경우, 아이디어가 매우 창의적인 경우 등을 고려하여 선정
#   - <font color='red'>학생 투표 기한: ~ 1월 22일(목) 23시 59분
#   - 투표에 참여하지 않으면 감점 2점</font>
#
# - 투표를 위한 설문지는 응답자 본인의 정보(이름, 학번)를 함께 기록되며, 투표결과는 취합하여 최종 점수에 반영됨
# - 학생 투표 점수
#   - 비율은 전체 발표자 수에 대한 비율입니다.
#   - 상위 10% 미만: 3점
#   - 상위 10 ~ 30% 미만: 2.5점
#   - 상위 30 ~ 50% 미만: 2점
#   - 상위 50% 이하: 1점

# %% [markdown]
# ##6.기여도평가(5점)
# - <font color='red'> 피드백 마감 기한: ~ 1월 22일(목) 23시 59분</font>
# - 1월 22일(목) 수업시간에 함께 영상을 시청하고, 시청 후 잠시 시간을 내어 패들렛에 피드백을 작성합니다.
# - 반드시 1인당 1개 이상의 피드백을 작성해야 합니다.
# - 피드백을 전혀 작성하지 않을 경우, 1점 감점됩니다.
# - 패들렛에 15개 이상 작성한 학생들에게 5점을 부여합니다.

# %% [markdown]
# # 프로젝트 보고서 작성요령
#
# • **0.프로젝트 요약:** 공백포함 500글자 이내로 적어주세요.
#
# • **1.실행환경:** 코드가 실행되는 환경을 적어주세요.
#
# • **2.데이터 출처:** 사용된 데이터를 어디에서 어떻게 수집했는지 적어주세요.
#
# • **3.전체코드**: 진행 순서대로 목차 만들어서 코드 넣어주고, 반드시 실행결과가 보이도록 제출해주세요.
#
# • **4.생성형 AI질문 리스트**: AI를 사용한 경우, 질문 리스트를 적어주고, 그 답을 어떻게 활용했는지 적어주세요.
#
# • **4.소감**에는 프로젝트를 진행하면서 역할 분담, 어려웠던 점, 느낀 점 등을 자유롭게 기술해주세요.

# %% [markdown]
# # 프로젝트 주제 제안서
# - 제출했던 주제 제안서를 아래에 복사하여 붙여 넣습니다.
# - 제출 이후 주제 제안서 내용이 변경된 경우, 변경된 내용을 넣으시면 됩니다.

# %% [markdown]
# # 프로젝트명: 적어주세요.
# - 학과/학번/이름: 적어주세요.

# %% [markdown]
# ## 0.프로젝트 요약(공백포함 500글자 이내)
# - 목적/내용/결론
#
#
# 예)대학가별 식당 상권의 전반적인 특성을 알아보고자 하였다. 종류별 식당 분포도를 통해 해당 상권에서는 어떠한 종류의 음식이 강세인지, 리뷰 수 분석을 통해 실제로 어떤 종류의 음식집이 인기가 많은지를 조사하였다. 식신 사이트를 크롤링해 정보를 수집했고, 막대 그래프와 원 그래프 등으로 시각화했다. 그 결
# 과, 리뷰 수는 건대입구, 신촌, 안암, 샤로수길, 왕십리 순서였다. 건대 주변에 맛집이 많을 가능성이 있다. 그리고 샤로수길의 성장이 두드러졌다. 상권별 테마 비교하면, 왕십리 제외 모든 대학가에서 일중세계음식, 한식, 양식 순으로 식당이 많았다. 일중세계음식에는 일식, 중식, 그 외 세계음식이 모두 포함되어 있어 일중세계음식 식당의 수가 많게 측정되는 경향있었지만, 그럼에도 불구하고 한양대에서는 한식이 우세했다. 본 분석에는 '식신 사이트'에 대한 편향성과 일식, 중식, 세계음식을 하나의 카테고리로 통합하여 조사하여 보다 세부적인 테마별 분석이 이루어지지 못했다는 한계를 가지고 있다.

# %% [markdown]
# ## 1.실행환경
# - OS:
# - 파이썬 툴:
# - 데이터 수집 방법:
# - 필요 모듈:
#
# 예
# ```
# OS(윈도우, 리눅스, 맥 등)
# 파이썬 툴(colab, jupyter notebook, vs code 등)
# 데이터 출처 또는 수집방법(예, 인구데이터: 서울열린광장, 스타벅스 매장 데이터: 스타벅스 홈페이지에서 크롤링)
# 필요 모듈(bs4, selenium 등)
#
# ```

# %% [markdown]
# ## 2.사용된 데이터 출처

# %% [markdown]
# - 사용된 데이터를 어디에서 어떻게 수집했는지 적어주세요.

# %% [markdown]
# ## 3.전체코드
#
# - 진행 순서대로 목차 만들고 셀을 분리하여 코드 넣어주고 실행한 후, 반드시 실행결과가 보이도록 제출해주세요.
# - 설명과 구현방법을 자세히 작성하세요.

# %% [markdown]
# ##4.생성형 AI질문 리스트

# %% [markdown]
# - ChatGPT등 AI를 사용한 경우, 활용한 질문 리스트를 적어주고, 그 답을 어떻게 활용했는지 적어주세요.

# %% [markdown]
# ## 5.소감
# - 프로젝트를 진행하면서 어려웠던 점, 느낀 점 등을 자유롭게 기술하시면 됩니다.
